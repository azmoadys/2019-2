# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series({'Kim': 100, 'Na': 141, "Park": 129, "Lee": 124})
s1.name = 'Math'
print(s1)
# Out:
# Kim     100
# Na      141
# Park    129
# Lee     124
# Name: Math, dtype: int64

# %%
s2 = pd.Series({'Kim': 100, 'Na': 141, "Park": 129, "Lee": 124})
#s2.name = 'Math'
print(s2)
# Out:
# Kim     100
# Na      141
# Park    129
# Lee     124
# dtype: int64

# %%
s3 = pd.Series([100, 141, 129,124])
s3.name = 'New'
print(s3)
# Out:
# 0    100
# 1    141
# 2    129
# 3    124
# Name: New, dtype: int64

# %%
df = pd.DataFrame({'birth':['Ko', 'US'], 'Age':[20,30]})
print(df)
# Out:
#   birth  Age
# 0    Ko   20
# 1    US   30

# %%
df['Sex'] = ['Male','Female']

# %%
df.loc[2] = ['Jp', 25,'Female']
print(df)
# Out:
#   birth  Age     Sex
# 0    Ko   20    Male
# 1    US   30  Female
# 2    Jp   25  Female

# %%
df2 = pd.DataFrame(s1)

# %%
print(df2)
# Out:
#       Math
# Kim    100
# Na     141
# Park   129
# Lee    124

# %%
df2["Eng"] = s2
df2["Art"] = [1,2,3,4]
print(df2)
# Out:
#       Math  Eng  Art
# Kim    100  100    1
# Na     141  141    2
# Park   129  129    3
# Lee    124  124    4

# %%
df2[['Math', 'Eng']]
# Out:
#       Math  Eng
# Kim    100  100
# Na     141  141
# Park   129  129
# Lee    124  124

# %%
df2.loc[['Kim', 'Na']]
# Out:
#      Math  Eng  Art
# Kim   100  100    1
# Na    141  141    2

# %%
df2.loc['Kim']
# Out:
# Math    100
# Eng     100
# Art       1
# Name: Kim, dtype: int64

# %%
df2
# Out:
#       Math  Eng  Art
# Kim    100  100    1
# Na     141  141    2
# Park   129  129    3
# Lee    124  124    4

# %%
print(df2.sum())
# Out:
# Math    494
# Eng     494
# Art      10
# dtype: int64

# %%
print(df2.sum(axis=1))
# Out:
# Kim     201
# Na      284
# Park    261
# Lee     252
# dtype: int64

# %%
print(df2.mean(axis=1))
# Out:
# Kim     67.000000
# Na      94.666667
# Park    87.000000
# Lee     84.000000
# dtype: float64

# %%
print(df2['Math'].mean())
# Out:
# 123.5

# %%
print(df2.loc)

# %%
train = pd.read_csv('./train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
sns.relplot(data= train, x='Age', y='Survived')

# %%
sns.relplot(data= train, x='Age', y='Survived', hue='Sex', aspect=4)

# %%
sns.catplot(data=train, x='Pclass', y='Fare', aspect=2)
sns.catplot(data=train, x='Pclass', y='Fare', hue = 'Sex',jitter = False, aspect = 2)
sns.catplot(data=train, x='Pclass', y='Fare', aspect=2, hue = 'Sex')

# %%
sns.pairplot(data=train, hue='Sex',
             x_vars = ['Pclass', 'Age', 'Fare'],
             y_vars = ['Survived', 'Embarked', 'Parch'], height = 3)

# %%
sns.catplot(data=train, x='Pclass', y='Fare', hue='Sex', kind='box')
sns.catplot(data=train, x='Pclass', y='Fare', kind='box')

# %%
live = train.loc[train['Survived'] == 1, 'PassengerId'].count()

# %%
dead = train['PassengerId'].count() - train.loc[train['Survived'] == 1, 'PassengerId'].count()

# %%
x=[0]
y = [dead]

plt.xlabel('Survived')
plt.ylabel('Count')

plt.bar(x,y, color = 'red')
x=[1]
y = [live]
plt.bar(x,y, color = 'blue')
plt.legend(['dead', 'Survived'])
plt.show()

# %%
test = pd.read_csv('./test.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
train['Age'].fillna(df['Age'].mean())
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  0.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.0      1
# 2                             Heikkinen, Miss. Laina  female  0.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.0      1
# 4                           Allen, Mr. William Henry    male  0.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.loc[train['Age'] <10,'Age'] = 0
train.loc[(train['Age'] >=10) & (train['Age']<20),'Age'] = 1
train.loc[(train['Age'] >=20) & (train['Age']<30),'Age'] = 2
train.loc[(train['Age'] >=30) & (train['Age']<40),'Age'] = 3
train.loc[(train['Age'] >=40) & (train['Age']<50),'Age'] = 4
train.loc[train['Age'] >=50,'Age'] = 5
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
test.loc[train['Age'] <10,'Age'] = 0
test.loc[(train['Age'] >=10) & (train['Age']<20),'Age'] = 1
test.loc[(train['Age'] >=20) & (train['Age']<30),'Age'] = 2
test.loc[(train['Age'] >=30) & (train['Age']<40),'Age'] = 3
test.loc[(train['Age'] >=40) & (train['Age']<50),'Age'] = 4
test.loc[train['Age'] >=50,'Age'] = 5
test
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
train['Fam'] = train['Parch'] +train['SibSp']
test['Fam'] = test['Parch'] +test['SibSp']

# %%
print(train.loc[train['Survived'] == 0, 'Pclass'].mean())
print(train.loc[train['Survived'] == 1, 'Pclass'].mean())
print(train.loc[train['Survived'] == 0, 'Fare'].mean())
print(train.loc[train['Survived'] == 1, 'Fare'].mean())
# Out:
# 2.5318761384335153
# 1.9502923976608186
# 22.117886885245902
# 48.39540760233918

# %%
train.loc[train['Sex'] =='male','Sex'] = 0
train.loc[train['Sex'] =='female','Sex'] = 1
test.loc[test['Sex'] =='male','Sex'] = 0
test.loc[test['Sex'] =='female','Sex'] = 1

# %%
test['Age'] = test['Age'].fillna(df['Age'].mean())

# %%
train = train[['Survived', 'Sex', 'Age', 'Pclass', 'Fam', 'Fare']]
test = test[['Sex', 'Age', 'Pclass', 'Fam', 'Fare']]

# %%
x_train = train[['Sex', 'Age', 'Pclass', 'Fam', 'Fare']]
y_train = train[['Survived']]
x_train
# Out:
#      Sex  Age  Pclass  Fam      Fare
# 0      0  0.0       3    1    7.2500
# 1      1  1.0       1    1   71.2833
# 2      1  1.0       3    0    7.9250
# 3      1  1.0       1    1   53.1000
# 4      0  0.0       3    0    8.0500
# 5      0  0.0       3    0    8.4583
# 6      0  0.0       1    0   51.8625
# 7      0  0.0       3    4   21.0750
# 8      1  1.0       3    2   11.1333
# 9      1  1.0       2    1   30.0708
# 10     1  1.0       3    2   16.7000
# 11     1  1.0       1    0   26.5500
# 12     0  0.0       3    0    8.0500
# 13     0  0.0       3    6   31.2750
# 14     1  1.0       3    0    7.8542
# 15     1  1.0       2    0   16.0000
# 16     0  0.0       3    5   29.1250
# 17     0  0.0       2    0   13.0000
# 18     1  1.0       3    1   18.0000
# 19     1  1.0       3    0    7.2250
# 20     0  0.0       2    0   26.0000
# 21     0  0.0       2    0   13.0000
# 22     1  1.0       3    0    8.0292
# 23     0  0.0       1    0   35.5000
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier()
tree.fit(x_train, y_train)
print(tree.score(x_train, y_train))
# Out:
# 0.9180695847362514

# %%
test
# Out:
#      Sex  Age  Pclass  Fam      Fare
# 0      0  0.0       3    0    7.8292
# 1      1  0.0       3    1    7.0000
# 2      0  0.0       2    0    9.6875
# 3      0  0.0       3    0    8.6625
# 4      1  0.0       3    2   12.2875
# 5      0  0.0       3    0    9.2250
# 6      1  0.0       3    0    7.6292
# 7      0  0.0       2    2   29.0000
# 8      1  0.0       3    0    7.2292
# 9      0  0.0       3    2   24.1500
# 10     0  0.0       3    0    7.8958
# 11     0  0.0       1    0   26.0000
# 12     1  0.0       1    1   82.2667
# 13     0  0.0       2    1   26.0000
# 14     1  0.0       1    1   61.1750
# 15     1  0.0       2    1   27.7208
# 16     0  0.0       2    0   12.3500
# 17     0  0.0       3    0    7.2250
# 18     1  0.0       3    1    7.9250
# 19     1  0.0       3    0    7.2250
# 20     0  0.0       1    1   59.4000
# 21     0  0.0       3    1    3.1708
# 22     1  0.0       1    0   31.6833
# 23     0  0.0       1    1   61.3792
# ...

# %%
test
# Out:
#      Sex  Age  Pclass  Fam      Fare
# 0      0  0.0       3    0    7.8292
# 1      1  0.0       3    1    7.0000
# 2      0  0.0       2    0    9.6875
# 3      0  0.0       3    0    8.6625
# 4      1  0.0       3    2   12.2875
# 5      0  0.0       3    0    9.2250
# 6      1  0.0       3    0    7.6292
# 7      0  0.0       2    2   29.0000
# 8      1  0.0       3    0    7.2292
# 9      0  0.0       3    2   24.1500
# 10     0  0.0       3    0    7.8958
# 11     0  0.0       1    0   26.0000
# 12     1  0.0       1    1   82.2667
# 13     0  0.0       2    1   26.0000
# 14     1  0.0       1    1   61.1750
# 15     1  0.0       2    1   27.7208
# 16     0  0.0       2    0   12.3500
# 17     0  0.0       3    0    7.2250
# 18     1  0.0       3    1    7.9250
# 19     1  0.0       3    0    7.2250
# 20     0  0.0       1    1   59.4000
# 21     0  0.0       3    1    3.1708
# 22     1  0.0       1    0   31.6833
# 23     0  0.0       1    1   61.3792
# ...

# %%
train
# Out:
#      Survived  Sex  Age  Pclass  Fam      Fare
# 0           0    0  0.0       3    1    7.2500
# 1           1    1  1.0       1    1   71.2833
# 2           1    1  1.0       3    0    7.9250
# 3           1    1  1.0       1    1   53.1000
# 4           0    0  0.0       3    0    8.0500
# 5           0    0  0.0       3    0    8.4583
# 6           0    0  0.0       1    0   51.8625
# 7           0    0  0.0       3    4   21.0750
# 8           1    1  1.0       3    2   11.1333
# 9           1    1  1.0       2    1   30.0708
# 10          1    1  1.0       3    2   16.7000
# 11          1    1  1.0       1    0   26.5500
# 12          0    0  0.0       3    0    8.0500
# 13          0    0  0.0       3    6   31.2750
# 14          0    1  1.0       3    0    7.8542
# 15          1    1  1.0       2    0   16.0000
# 16          0    0  0.0       3    5   29.1250
# 17          1    0  0.0       2    0   13.0000
# 18          0    1  1.0       3    1   18.0000
# ...

# %%
facet = sns.FacetGrid(train, hue='Survived', aspect=4)
facet.map(sns.kdeplot, 'Age')
facet.
