# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#O(N^6)
x6=[5,10,15,20,25,50,75,100,150,200]
y6=[0.014,0.373,3.597,17.184,48.637,2481.9,26613.5,145210,1882870,9678580]
plt.plot(x6,y6)
#O(N^4)
x4=[5,10,15,20,25,50,75,100,150,200,300,400,500,1000]#,2000]
y4=[0.015,0.077,0.388,1.353,3.073,41.394,172.072,520.183,2555.19,7889.92,40797.1,130870,332539,5803350]
plt.plot(x4,y4)
#O(N^3)
x3=[5,10,15,20,25,50,75,100,150,200,300,400,500,1000,2000]
y3=[0.055,0.046,0.112,0.188,0.392,2.089,7.28,15.916,46.216,109.313,359.757,891.547,1701.8,21123.6,228568]
plt.plot(x3,y3)

plt.ylabel("Time(ms)")
plt.xlabel("n*n Matrix")
plt.legend(["O(N^6)","O(N^4)","O(N^3)"])
plt.axis([0,2000,0,5500000])
plt.show()
